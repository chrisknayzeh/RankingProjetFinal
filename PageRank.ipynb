# %% [markdown]
# # Libraries

# %%
import numpy as np
import time

from utils import readText, printMat, rmRed, convertStrNum, randSelect, randEdge

from tpVector import tpVector
from pagerank import pagerank

# %% [markdown]
# # Setting Up the Data Directory

# %% [markdown]
# Set up the directory for the data here. String should end with /

# %%
directory = 'D:/Coding Stuffs/PageRank Project (final)/Data/'

# %% [markdown]
# # Graph 1: wb-cs-stanford

# %%
# Set Up the Graph Name here

graphName = "wb-cs-stanford.txt"

# %% [markdown]
# ## Data Processing

# %%
# Data Processing

lines, rows = readText(directory+graphName)
lines, vertices,total_edges = rmRed(lines)

lines = convertStrNum(lines)
# print(lines)

print("Number of Nodes: ", vertices)
print("Number of Edges: ", total_edges)
# Out:
# Number of Nodes:  9914
# Number of Edges:  36854

# %% [markdown]
# ## Creating the Edge List

# %%
#Creating the edge
tstart = time.time()
edge_list = []

for line in lines:
  edge = line
  edge.pop(0)
  edge.pop(0)
  
  for number in edge:
    if not isinstance(number, int):
      edge.remove(number)
  
  edge_list.append(edge)

tend = time.time()
print(edge_list)
print("Time Needed: ", tend - tstart)
# Out:
# [[], [], [], [5, 9, 16, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517], [6], [5, 8, 9, 16, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517], [5, 8, 9, 16, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517], [5, 8, 9, 16, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517], [10], [5, 9, 11, 12, 13, 14, 16, 24, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517], [36, 2238, 6517], [36, 2238, 6517], [36, 2238, 6517], [36, 2238, 6517], [5, 9, 11, 12, 13, 14, 16, 24, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517], [17], [5, 9, 16, 19, 24, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517], [5, 9, 16, 27, 36, 38, 47, 52, 2238, 6517], [5, 9, 16, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517], [], [22], [5, 9, 16, 23, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517], [23], [25], [5, 9, 16, 26, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517], [5, 9, 16, 26, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517], [28], [5, 9, 16, 24, 27, 29, 30, 31, 32, 34, 36, 38, 47, 52, 2238, 6517], [5, 9, 16, 27, 29, 30, 31, 32, 34, 36, 38, 47, 52, 2238, 6517], [5, 9, 16, 27, 29, 30, 31, 32, 34, 36, 38, 47, 52, 2238, 6517], [5, 9, 16, 27, 29, 30, 31, 32, 34, 36, 38, 47, 52, 2238, 6517], [5, 9, 16, 27, 29, 30, 31, 32, 34, 36, 38, 47, 52, 2238, 6517], [5, 9, 16, 27, 36, 38, 47, 52, 2238, 6517], [5, 9, 16, 27, 29, 30, 31, 32, 34, 36, 38, 47, 52, 2238, 6517], [5, 9, 16, 27, 36, 38, 47, 52, 2238, 6517], [37], [5, 9, 16, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517], [39], [5, 9, 16, 24, 27, 29, 30, 32, 34, 36, 38, 40, 44, 45, 47, 52, 2238, 6517], [5, 9, 16, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 5072, 6517, 7741, 8055, 8739, 8849, 8853, 9206], [5, 9, 16, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517], [7, 15, 18, 20, 33, 35, 36, 40, 41, 42, 43, 44, 46, 51, 58, 2238, 6517], [5, 9, 16, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 5121, 5462, 5677, 6217, 6517, 7715, 7968, 7970, 8053, 8892, 8912, 9667, 9680, 9682], [5, 9, 16, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 5002, 5121, 5179, 6194, 6517], [5, 7, 9, 15, 16, 18, 27, 29, 30, 33, 36, 38, 41, 42, 43, 46, 47, 51, 52, 58, 2238, 6517], [5, 9, 16, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517], [48], [5, 9, 16, 24, 27, 29, 30, 32, 34, 36, 38, 47, 49, 50, 52, 2238, 6517], [5, 9, 16, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517], [5, 9, 16, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517], [49, 50], [53], [5, 9, 16, 24, 27, 29, 30, 32, 34, 36, 38, 47, 52, 54, 2238, 6517], [5, 9, 16, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517], [7, 15, 18, 20, 33, 36, 42, 51, 54, 57, 58, 2238, 6517], [7, 15, 18, 20, 33, 36, 42, 51, 54, 55, 58, 2238, 6517], [5, 9, 16, 27, 36, 38, 47, 52, 2238, 6517], [5, 9, 16, 27, 29, 30, 32, 34, 36, 38, 47, 52, 55, 56, 2238, 6517], [], [61], [60, 62], [], [105, 222], [73, 82, 126], [64, 126], [64, 65], [64, 65], [64, 65], [64, 65], [64, 65], [64, 65], [64, 65], [74, 75], [], [74], [74, 75], [74, 75], [74, 75], [74, 75], [74, 75], [74, 75], [83, 84], [73, 90, 225], [83], [83, 84], [83, 84], [83, 84], [83, 84], [83, 84], [92, 93], [92, 93], [113, 224], [92], [92, 93], [92, 93], [92, 93], [92, 93], [92, 93], [92, 93], [92, 93], [92, 93], [92, 93], [92, 93], [92, 93], [66, 85, 94, 119, 125, 150, 222, 236, 242, 245], [111, 112], [112], [112], [112], [112], [150], [], [114, 115], [], [], [117, 118], [73, 239], [117, 150], [117, 118], [117, 118], [117, 118], [117, 118], [], [123], [123, 124], [], [], [], [], [], [], [], [140, 220], [144, 219], [145], [147, 217], [143, 149, 213], [214, 218], [141], [], [160, 197, 207, 208, 209, 210], [], [148], [175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 198, 203, 204, 219], [141, 144, 145, 146, 159, 173, 174], [128, 129, 130, 131, 132, 207], [144, 145, 146, 147, 153, 154, 159, 171, 172, 201, 202], [212], [212], [133, 134, 135, 136, 137, 138, 139], [], [], [], [], [], [], [151, 157, 211, 221], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [],  ...
# Time Needed:  0.09574365615844727

# %% [markdown]
# ## Removing 10% of edges

# %%
#Removing random edges
tstart = time.time()

threshold = 0.1
counter = 0
new_edges = edge_list
while counter < total_edges*threshold:
  idx = randSelect(len(new_edges))
  for neighbor in new_edges[idx]:
    x = randEdge(threshold)
    if x:
      new_edges[idx].remove(neighbor)
      counter+=1
  
new_edges_num = 0

for item in edge_list:
  new_edges_num+=len(item)

tend = time.time()
for i in range(10):
  print(new_edges[i])

print("Time Neede: ", tend-tstart)
# Out:
# []
# []
# []
# [5, 9, 16, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517]
# [6]
# [5, 8, 9, 16, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517]
# [5, 8, 16, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517]
# [5, 9, 27, 29, 30, 32, 34, 36, 38, 47, 52, 2238, 6517]
# [10]
# [5, 9, 11, 13, 14, 24, 27, 29, 30, 32, 34, 38, 47, 52, 2238]
# Time Neede:  0.0608365535736084

# %%
len(new_edges)
# Out:
# 9914

# %%
len(lines)
# Out:
# 9914

# %% [markdown]
# ### Creating the Teleport Vector and Running PageRank

# %%
#Creating Teleport vector
tstart = time.time()
teleport = tpVector(new_edges)
tend=time.time()
print("Time Needed: ", tend-tstart)
# Out:
# Time Needed:  0.002992391586303711

# %%
tstart = time.time()
ranking,iterations = pagerank(new_edges, 0.85, 10**-6, teleport)
tend=time.time()
print("Time Needed: ", tend-tstart)
# Out:
# Time Needed:  0.06482696533203125

# %%
for i in range(10):
    print(ranking[i])

print("Iterations: ", iterations)
# Out:
# 1.0174242512737567e-08
# 1.0174242512737567e-08
# 1.0174242512737567e-08
# 2.784050213273728e-10
# 1.98860729519552e-11
# 2.9829109427932823e-10
# 2.784050213273728e-10
# 2.585189483754176e-10
# 1.98860729519552e-11
# 2.9829109427932823e-10
# Iterations:  95

# %% [markdown]
# ## Removing 20% of edges

# %%
#Removing random edges
tstart = time.time()
threshold = 0.2
counter = 0
new_edges = edge_list
while counter < total_edges*threshold:
  idx = randSelect(len(new_edges))
  for neighbor in new_edges[idx]:
    x = randEdge(threshold)
    if x:
      new_edges[idx].remove(neighbor)
      counter+=1
  
new_edges_num = 0

for item in edge_list:
  new_edges_num+=len(item)

tend = time.time()

for i in range(10):
  print(new_edges[i])

print("Time Needed: ", tend-tstart)
# Out:
# []
# []
# []
# [29, 38]
# []
# [16, 38, 52, 2238, 6517]
# [8, 34, 52, 2238, 6517]
# [27, 30, 47, 6517]
# [10]
# [5, 11, 24, 29, 32, 47, 52, 2238]
# Time Needed:  0.1246793270111084

# %%
len(new_edges)
# Out:
# 9914

# %%
len(lines)
# Out:
# 9914

# %% [markdown]
# ### Creating the Teleport Vector and Running PageRank

# %%
#Creating Teleport vector
tstart = time.time()
teleport = tpVector(new_edges)
tend=time.time()

print("Time Needed: ", tend-tstart)
#print(teleport)
# Out:
# Time Needed:  0.004987001419067383

# %%
tstart = time.time()
ranking,iterations = pagerank(new_edges, 0.85, 10**-6, teleport)
tend = time.time()
print("Time Needed: ", tend - tstart)
# Out:
# Time Needed:  0.02692866325378418

# %%
for i in range(10):
    print(ranking[i])
print("Iterations: ",iterations)
# Out:
# 1.0173880691959264e-08
# 1.0173880691959264e-08
# 1.0173880691959264e-08
# 7.213954538126053e-09
# 1.0173880691959264e-08
# 1.8034886345315125e-08
# 1.8034886345315125e-08
# 1.4427909076252106e-08
# 3.6069772690630264e-09
# 2.5248840883441168e-08
# Iterations:  63

# %% [markdown]
# # Graph 2: Stanford

# %%
# Set Up the Graph Name here

graphName = "Stanford.txt"

# %% [markdown]
# ## Data Processing

# %%
# Data Processing

lines, rows = readText(directory+graphName)
lines, vertices,total_edges = rmRed(lines)

lines = convertStrNum(lines)
# print(lines)

print("Number of Nodes: ", vertices)
print("Number of Edges: ", total_edges)
# Out:
# Number of Nodes:  281903
# Number of Edges:  2312497

# %% [markdown]
# ## Creating the Edge List

# %%
#Creating the edge list
tstart = time.time()
edge_list = []

for line in lines:
  edge = line
  edge.pop(0)
  edge.pop(0)
  
  for number in edge:
    if not isinstance(number, int):
      edge.remove(number)
  
  edge_list.append(edge)

tend = time.time()
for i in range(10):
  print(edge_list[i])

print("Time Needed: ", tend-tstart)
# Out:
# []
# [872, 1281, 12094, 17093, 17794, 19147, 20923, 25202, 31702, 35877, 52411, 53625, 54582, 59348, 64930, 72940, 73764, 78295, 84477, 98008, 98628, 100193, 102355, 105318, 105730, 115926, 120097, 140864, 151832, 152086, 155610, 158672, 161354, 161689, 163550, 163990, 164599, 172329, 172765, 175133, 175799, 178642, 180755, 181235, 181714, 181865, 185567, 190453, 192783, 200263, 204189, 204604, 210870, 213966, 224289, 225119, 228300, 234603, 241596, 243294, 246897, 251658, 252915, 253992, 257281, 259633, 266555, 276060, 278619, 280935]
# [96493]
# []
# [6545, 14395, 59745]
# [6540, 59742]
# [45366]
# []
# [174822]
# [6536, 118572]
# Time Needed:  257.2230079174042

# %% [markdown]
# ## Removing 10% of edges

# %%
#Removing random edges
tstart = time.time()

threshold = 0.1
counter = 0
new_edges = edge_list
while counter < total_edges*threshold:
  idx = randSelect(len(new_edges))
  for neighbor in new_edges[idx]:
    x = randEdge(threshold)
    if x:
      new_edges[idx].remove(neighbor)
      counter+=1
  
new_edges_num = 0

for item in edge_list:
  new_edges_num+=len(item)

tend = time.time()

for i in range(10):
  print(new_edges[i])

print("Time Needed: ", tend-tstart)
# Out:
# []
# [872, 1281, 12094, 17093, 17794, 19147, 20923, 25202, 31702, 35877, 52411, 53625, 54582, 59348, 64930, 72940, 78295, 84477, 98008, 98628, 100193, 102355, 105318, 105730, 115926, 120097, 140864, 151832, 152086, 155610, 158672, 161354, 161689, 163550, 163990, 164599, 172329, 172765, 175133, 175799, 178642, 180755, 181235, 181714, 181865, 185567, 190453, 192783, 204189, 204604, 210870, 213966, 224289, 225119, 228300, 234603, 241596, 243294, 251658, 252915, 253992, 257281, 259633, 276060, 278619, 280935]
# [96493]
# []
# [6545, 14395, 59745]
# [6540, 59742]
# [45366]
# []
# [174822]
# [6536, 118572]
# Time Needed:  12.777822971343994

# %%
len(new_edges)
# Out:
# 281903

# %%
len(lines)
# Out:
# 281903

# %% [markdown]
# ### Creating the Teleport Vector and Running PageRank

# %%
#Creating Teleport vector
tstart = time.time()
teleport = tpVector(new_edges)
tend - time.time()
print("Time Needed: ", tend-tstart)
#print(teleport)
# Out:
# Time Needed:  -44.381630182266235

# %%
tstart = time.time()
ranking,iterations = pagerank(new_edges, 0.85, 10**-6, teleport)
tend = time.time()

print("Time Needed: ", tend-tstart)
# Out:
# Time Needed:  3.9663918018341064

# %%
for i in range(10):
    print(ranking[i])

print("Iterations: ", iterations)
# Out:
# 1.2583475408363767e-11
# 4.382577776909926e-21
# 6.640269358954428e-23
# 1.2583475408363767e-11
# 1.9920808076863267e-22
# 1.3280538717908857e-22
# 6.640269358954428e-23
# 1.2583475408363767e-11
# 6.640269358954428e-23
# 1.3280538717908857e-22
# Iterations:  237

# %% [markdown]
# ## Removing 20% of edges

# %%
#Removing random edges
tstart = time.time()
threshold = 0.2
counter = 0
new_edges = edge_list
while counter < total_edges*threshold:
  idx = randSelect(len(new_edges))
  for neighbor in new_edges[idx]:
    x = randEdge(threshold)
    if x:
      new_edges[idx].remove(neighbor)
      counter+=1
  
new_edges_num = 0

for item in edge_list:
  new_edges_num+=len(item)

tend = time.time()
for i in range(10):
  print(new_edges[i])

print("Time Needed: ", tend-tstart)
# Out:
# []
# [872, 12094, 17093, 17794, 20923, 31702, 35877, 52411, 54582, 59348, 64930, 78295, 84477, 98008, 100193, 102355, 105318, 105730, 120097, 151832, 152086, 155610, 158672, 161689, 163550, 163990, 172329, 172765, 175133, 175799, 180755, 181714, 181865, 192783, 204189, 204604, 213966, 224289, 225119, 228300, 234603, 243294, 251658, 257281, 259633, 276060, 278619]
# []
# []
# [6545, 14395, 59745]
# [6540]
# [45366]
# []
# []
# [6536, 118572]
# Time Needed:  18.978238821029663

# %%
len(new_edges)
# Out:
# 281903

# %%
len(lines)
# Out:
# 281903

# %% [markdown]
# ### Creating Teleport Vector and Running PageRank

# %%
#Creating Teleport vector
tstart = time.time()

teleport = tpVector(new_edges)

tend = time.time()
print("Time Needed: ", tend-tstart)
# Out:
# Time Needed:  0.13065147399902344

# %%
tstart = time.time()
ranking,iterations = pagerank(new_edges, 0.85, 10**-6, teleport)
tend = time.time()

print("Time Needed: ", tend-tstart)
# Out:
# Time Needed:  2.6578898429870605

# %%
for i in range(10):
    print(ranking[i])
print("Iterations: ", iterations)
# Out:
# 1.2583475408163831e-11
# 2.6490721969729023e-15
# 1.2583475408163831e-11
# 1.2583475408163831e-11
# 1.6908971470039776e-16
# 5.636323823346594e-17
# 5.636323823346594e-17
# 1.2583475408163831e-11
# 1.2583475408163831e-11
# 1.1272647646693187e-16
# Iterations:  153

# %% [markdown]
# # Graph 3: India

# %%
# Set Up the Graph Name here

graphName = "INDIA.txt"

# %% [markdown]
# ## Data Processing

# %%
# Data Processing

lines, rows = readText(directory+graphName)
lines, vertices,total_edges = rmRed(lines)

lines = convertStrNum(lines)
# print(lines)

print("Number of Nodes: ", vertices)
print("Number of Edges: ", total_edges)
# Out:
# Number of Nodes:  1382908
# Number of Edges:  16917053

# %% [markdown]
# ## Creating the Edge List

# %%
#Creating the edge list
tstart = time.time()
edge_list = []

for line in lines:
  edge = line
  edge.pop(0)
  edge.pop(0)
  
  for number in edge:
    if not isinstance(number, int):
      edge.remove(number)
  
  edge_list.append(edge)

tend = time.time()
for i in range(10):
  print(edge_list[i])

print("Time Needed: ", tend-tstart)
# Out:
# [1, 3, 161227, 378785, 378804]
# [1, 3, 378804]
# [4, 378804]
# [4, 5, 6, 7, 8, 9, 10, 378804]
# [4, 5, 6, 7, 8, 9, 10, 378804]
# [4, 5, 6, 7, 8, 9, 10, 378804]
# [4, 5, 6, 7, 8, 9, 10, 378804]
# [4, 5, 6, 7, 8, 9, 10, 378804]
# [4, 5, 6, 7, 8, 9, 10, 378804]
# [184, 185, 187, 188, 189, 1347902]
# Time Needed:  95.07967686653137

# %% [markdown]
# ## Removing 10% of edges

# %%
#Removing random edges
tstart = time.time()

threshold = 0.1
counter = 0
new_edges = edge_list
while counter < total_edges*threshold:
  idx = randSelect(len(new_edges))
  for neighbor in new_edges[idx]:
    x = randEdge(threshold)
    if x:
      new_edges[idx].remove(neighbor)
      counter+=1
  
new_edges_num = 0

for item in edge_list:
  new_edges_num+=len(item)

tend = time.time()

for i in range(10):
  print(new_edges[i])

print("Time Needed: ", tend-tstart)
# Out:
# [1, 3, 161227, 378785, 378804]
# [1, 3]
# [4, 378804]
# [5, 6, 7, 8, 9, 10, 378804]
# [4, 5, 6, 7, 9, 378804]
# [4, 5, 6, 7, 8, 9, 10]
# [4, 5, 7, 8, 9, 10, 378804]
# [4, 5, 6, 7, 8, 9, 10, 378804]
# [4, 6, 7, 8, 9, 10, 378804]
# [184, 185, 187, 188, 189, 1347902]
# Time Needed:  73.88367867469788

# %%
len(new_edges)
# Out:
# 1382908

# %%
len(lines)
# Out:
# 1382908

# %% [markdown]
# ### Creating the Teleport Vector and Running PageRank

# %%
#Creating Teleport vector
tstart = time.time()
teleport = tpVector(new_edges)
tend = time.time()
print("Time Needed: ", tend-tstart)
#print(teleport)
# Out:
# Time Needed:  -19.509415864944458

# %%
tstart = time.time()
ranking,iterations = pagerank(new_edges, 0.85, 10**-6, teleport)
tend = time.time()

print("Time Needed: ", tend-tstart)
# Out:
# d:\Coding Stuffs\PageRank Project (final)\Python\pagerank.py:21: RuntimeWarning: overflow encountered in double_scalars
#   temp_v[idx] += v[i-1]
# Time Needed:  44.00921368598938
# d:\Coding Stuffs\PageRank Project (final)\Python\pagerank.py:30: RuntimeWarning: invalid value encountered in subtract
#   while (np.linalg.norm(v-temp_v) > error):

# %%
for i in range(10):
    print(ranking[i])

print("Iterations: ", iterations)
# Out:
# 3.6155695100469446e-06
# 4.338683412056334e-06
# 1.4462278040187777e-06
# 5.061797314065723e-06
# 8.677366824112667e-06
# 1.7354733648225335e-05
# 1.7354733648225335e-05
# 5.134108704266661e-05
# 9.328169335921118e-05
# 4.338683412056334e-06
# Iterations:  0

# %% [markdown]
# ## Removing 20% of edges

# %%
#Removing random edges
tstart = time.time()
threshold = 0.2
counter = 0
new_edges = edge_list
while counter < total_edges*threshold:
  idx = randSelect(len(new_edges))
  for neighbor in new_edges[idx]:
    x = randEdge(threshold)
    if x:
      new_edges[idx].remove(neighbor)
      counter+=1
  
new_edges_num = 0

for item in edge_list:
  new_edges_num+=len(item)

tend = time.time()
for i in range(10):
  print(new_edges[i])

print("Time Needed: ", tend-tstart)
# Out:
# [3, 378804]
# [1, 3]
# [4, 378804]
# [5, 6, 7, 8, 9, 10, 378804]
# [5, 6, 9]
# [4, 5, 6, 7, 8, 10]
# [4, 5, 8, 9, 10, 378804]
# [4, 6, 7, 8, 10, 378804]
# [4, 6, 7, 8, 10, 378804]
# [184, 185, 187, 188, 189, 1347902]
# Time Needed:  65.5746796131134

# %%
len(new_edges)
# Out:
# 1382908

# %%
len(lines)
# Out:
# 1382908

# %% [markdown]
# ### Creating Teleport Vector and Running PageRank

# %%
#Creating Teleport vector
tstart = time.time()

teleport = tpVector(new_edges)

tend = time.time()
print("Time Needed: ", tend-tstart)
# Out:
# Time Needed:  1.3414127826690674

# %%
tstart = time.time()
ranking,iterations = pagerank(new_edges, 0.85, 10**-6, teleport)
tend = time.time()

print("Time Needed: ", tend-tstart)
# Out:
# Time Needed:  412.32553267478943

# %%
for i in range(10):
    print(ranking[i])
print("Iterations: ", iterations)
# Out:
# 1.6360336300110042e-302
# 2.4540504450164895e-302
# 1.6360336300110042e-302
# 5.726117705038494e-302
# 2.4540504450164895e-302
# 1.1452235410076989e-301
# 1.1452235410076989e-301
# 3.1084638970209123e-301
# 6.135126112541241e-301
# 4.908100890032979e-302
# Iterations:  4193

# %% [markdown]
# # Graph 4: Stanford Berkeley

# %%
# Set Up the Graph Name here

graphName = "Stanford_BerkeleyV2.txt"

# %% [markdown]
# ## Data Processing

# %%
# Data Processing

lines, rows = readText(directory+graphName)
lines, vertices,total_edges = rmRed(lines)

lines = convertStrNum(lines)
# print(lines)

print("Number of Nodes: ", vertices)
print("Number of Edges: ", total_edges)
# Out:
# Number of Nodes:  68344
# Number of Edges:  7583376

# %% [markdown]
# ## Creating the Edge List

# %%
#Creating the edge list
tstart = time.time()
edge_list = []

for line in lines:
  edge = line
  edge.pop(0)
  edge.pop(0)
  
teleport Vector and Running PageRank

# %%
#Creating Teleport vector
tstart = time.time()
teleport = tpVector(new_edges)
tend - time.time()
print("Time Needed: ", tend-tstart)
#print(teleport)
# Out:
# Time Needed:  -0.6095716953277588

# %%
tstart = time.time()
ranking,iterations = pagerank(new_edges, 0.85, 10**-6, teleport)
tend = time.time()

print("Time Needed: ", tend-tstart)
# Out:
# Time Needed:  73.35342216491699

# %%
for i in range(10):
    print(ranking[i])

print("Iterations: ", iterations)
# Out:
# 8.470662276981845e-276
# 8.581852354603357e-276
# 2.0216377749359835e-278
# 1.0108188874679918e-278
# 8.531311410229978e-276
# 1.0108188874679918e-278
# 2.5785989819308868e-275
# 1.7032298253835882e-275
# 6.847287143708249e-275
# 2.5785989819308868e-275
# Iterations:  3856

# %% [markdown]
# ## Removing 20% of edges

# %%
#Removing random edges
tstart = time.time()
threshold = 0.2
counter = 0
new_edges = edge_list
while counter < total_edges*threshold:
  idx = randSelect(len(new_edges))
  for neighbor in new_edges[idx]:
    x = randEdge(threshold)
    if x:
      new_edges[idx].remove(neighbor)
      counter+=1
  
new_edges_num = 0

for item in edge_list:
  new_edges_num+=len(item)

tend = time.time()
for i in range(10):
  print(new_edges[i])

print("Time Needed: ", tend-tstart)
# Out:
# [3, 7, 16, 18, 20, 48819, 48824, 48894, 48900, 48912, 48916, 50361, 64694, 65087, 65088, 65089, 65090, 65091, 65092, 65093, 65094, 107258, 108260, 108346, 160844, 160919, 164450, 164543, 172459, 255096, 255111, 255168, 255196, 255205, 255463, 255464, 255655, 255675, 256797, 257160, 257187, 257328, 257406, 257407, 257409, 257410, 257411, 257412, 257414, 257415, 257416, 257417, 257419, 257420, 257421, 257422, 257423, 257426, 257428, 257430, 257431, 257432, 257435, 257437, 257446, 257447, 257448, 257449, 257450, 257453, 257455, 257457, 257458, 257460, 257462, 257464, 257469, 257470, 257471, 257474, 257476, 257479, 257480, 257489, 257491, 257498, 257500, 257502, 257512, 257514, 257516, 257526, 257532, 257536, 257540, 257545, 257547, 257551, 257553, 257557, 257559, 257561, 257563, 257566, 257568, 257569, 257577, 257581, 257591, 257594, 257595, 257596, 257598, 257602, 257605, 257606, 257608, 257609, 257611, 257613, 257615, 257617, 257619, 257620, 257630, 257634, 257638, 257640, 257643, 257644, 257646, 257648, 257655, 257657, 257661, 257663, 257664, 257668, 257670, 257676, 257677, 257678, 257679, 257680, 257682, 257684, 257687, 257690, 257694, 257695, 257697, 257698, 257702, 257704, 257709, 257711, 257715, 257719, 257720, 257722, 257725, 257729, 257731, 257733, 257735, 257739, 257743, 257744, 257747, 257752, 257754, 257756, 257757, 257759, 257760, 257762, 257764, 257765, 257767, 257768, 257774, 257779, 257781, 257786, 257787, 257790, 257792, 257794, 257796, 257798, 257800, 257805, 257807, 257809, 257811, 257813, 257815, 257816, 257818, 257820, 257821, 257823, 257830, 257833, 257835, 257837, 257839, 257840, 257842, 257843, 257847, 257849, 257853, 257856, 257857, 257869, 257871, 257875, 257877, 257879, 257881, 257883, 257885, 257889, 257891, 257893, 257895, 257897, 257899, 257903, 257905, 257908, 257909, 257912, 257928, 257930, 257936, 257942, 257957, 257962, 257964, 257968, 257973, 257979, 257987, 257993, 257995, 257997, 257999, 258000, 258002, 258004, 258005, 258007, 258009, 258011, 258015, 258017, 258019, 258022, 258030, 258033, 258035, 258037, 258039, 258041, 258043, 258045, 258047, 258051, 258053, 258055, 258057, 258058, 258059, 258063, 258065, 258067, 258069, 258071, 258079, 258082, 258083, 258088, 258095, 258105, 258107, 258108, 258110, 258112, 258120, 258122, 258124, 258126, 258128, 258132, 258134, 258136, 258140, 258141, 258142, 258145, 258146, 258150, 258152, 258153, 258154, 258157, 258161, 258163, 258164, 258166, 258170, 258172, 258174, 258176, 258178, 258180, 258185, 258187, 258188, 258197, 258199, 258202, 258206, 258210, 258212, 258214, 258218, 258225, 258230, 258232, 258238, 258239, 258240, 258241, 258242, 258249, 258254, 258255, 258257, 258261, 258263, 258266, 258269, 258271, 258272, 258274, 258276, 258281, 258285, 258288, 258290, 258292, 258293, 258294, 258298, 258302, 258304, 258310, 258319, 258320, 258322, 258324, 258326, 258327, 258329, 258333, 258338, 258340, 258345, 258346, 258347, 258349, 258350, 258356, 258360, 258367, 258369, 258373, 258375, 258376, 258378, 258380, 258384, 258388, 258390, 258395, 258399, 258401, 258404, 258408, 258412, 258414, 258416, 258420, 258422, 258424, 258426, 258428, 258430, 258432, 258434, 258442, 258454, 258458, 258459, 258460, 258462, 258468, 258473, 258475, 258476, 258478, 258480, 258481, 258483, 258484, 258486, 258488, 258490, 258492, 258494, 258496, 258498, 258500, 258502, 258503, 258506, 258507, 258509, 258511, 258513, 258514, 258515, 258516, 258518, 258520, 258522, 258524, 258525, 258527, 258529, 258531, 258533, 258534, 258535, 258536, 258537, 258538, 258539, 258541, 258543, 258544, 258545, 258546, 258547, 258548, 258550, 258553, 258554, 258556, 258557, 258558, 258559, 258560, 258561, 258562, 258563, 258564, 258565, 258567, 258568, 258569, 258570, 258571, 258572, 258573, 258575, 258577, 258578, 258579, 258580, 258581, 258582, 258583, 258584, 258586, 258588, 258590, 258592, 258594, 258596, 258597, 258599, 258600, 258602, 258603, 258604, 258605, 258606, 258607, 258608, 258610, 25861 ...
# [1, 7, 8, 9, 11, 13, 14, 15, 17, 19, 23]
# [7, 16]
# [7]
# [1, 7, 8, 14, 19, 23, 186138]
# [7]
# [2, 3, 5, 6, 8, 9, 11, 12, 13, 14, 16, 18, 19, 20, 23, 259152]
# [1, 5, 15, 19, 23]
# [1, 2, 7, 11, 13, 14, 15, 17, 19, 23]
# []
# Time Needed:  117.70367980003357

# %%
len(new_edges)
# Out:
# 683446

# %%
len(lines)
# Out:
# 683446

# %% [markdown]
# ### Creating Teleport Vector and Running PageRank

# %%
#Creating Teleport vector
tstart = time.time()

teleport = tpVector(new_edges)

tend = time.time()
print("Time Needed: ", tend-tstart)
# Out:
# Time Needed:  0.2712745666503906

# %%
tstart = time.time()
ranking,iterations = pagerank(new_edges, 0.85, 10**-6, teleport)
tend = time.time()

print("Time Needed: ", tend-tstart)
# Out:
# Time Needed:  45.12209749221802

# %%
for i in range(10):
    print(ranking[i])
print("Iterations: ", iterations)
# Out:
# 1.9550666729850834e-145
# 1.9783968242140182e-145
# 4.6660302457877384e-148
# 2.3330151228938692e-148
# 1.9690647637224465e-145
# 2.3330151228938692e-148
# 3.982456814779885e-145
# 3.931130482076212e-145
# 7.932251417839254e-145
# 2.140876366198558e-12
# Iterations:  2009

# %% [markdown]
# # Graph 5: Wikipedia

# %%
# Set Up the Graph Name here

graphName = "wikipedia.txt"

# %% [markdown]
# ## Data Processing

# %%
# Data Processing

lines, rows = readText(directory+graphName)
lines, vertices,total_edges = rmRed(lines)

lines = convertStrNum(lines)
# print(lines)

print("Number of Nodes: ", vertices)
print("Number of Edges: ", total_edges)
# Out:
# Number of Nodes:  1634989
# Number of Edges:  19753078

# %% [markdown]
# ## Creating the Edge List

# %%
#Creating the edge list
tstart = time.time()
edge_list = []

for line in lines:
  edge = line
  edge.pop(0)
  edge.pop(0)
  
  for number in edge:
    if not isinstance(number, int):
      edge.remove(number)
  
  edge_list.append(edge)

tend = time.time()
for i in range(10):
  print(edge_list[i])

print("Time Needed: ", tend-tstart)
# Out:
# [87]
# [143]
# [161]
# [521]
# [332]
# []
# [739]
# [463, 549, 1400, 1421, 1574, 2137, 2162, 3169, 3208, 3390, 3971, 4496, 4892, 5015, 5302, 5320, 5354, 5910, 6045, 7178, 7618, 7772, 8275, 8325, 8583, 8687, 8715, 8760, 8772, 8960, 9261, 9281, 9291, 9603, 9868, 9960, 10377, 10595, 10659, 11032, 11452, 11732, 11793, 11916, 12108, 13188, 13217, 13816, 13838, 13883, 14098, 14422, 14609, 14859, 15720, 15773, 16759, 17531, 17660, 18298, 18301, 18717, 18824, 19884, 19896, 20451, 20576, 20722, 20750, 20798, 20984, 21305, 21376, 21378, 21386, 22327, 23180, 23506, 23576, 23851, 24334, 24471, 24536, 24751, 25377, 25378, 25406, 25624, 26102, 26105, 26118, 26192, 26304, 26353, 26468, 26762, 26823, 26873, 27370, 27377, 27378, 27390, 27391, 27476, 27487, 27494, 27519, 27534, 27544, 27586, 27587, 27605, 27664, 28229, 29516, 29590, 29612, 29638, 29703, 29768, 30408, 31469, 33832, 33962, 35393, 35526, 36293, 36739, 37855, 38178, 38188, 38698, 39405, 39409, 39583, 40134, 40140, 40459, 42237, 42486, 42656, 43714, 45311, 45563, 45641, 45878, 46220, 46634, 47158, 47874, 52280, 53274, 55041, 58119, 59029, 59783, 60640, 61308, 61772, 62637, 66774, 67615, 68761, 69121, 69302, 70807, 70816, 71929, 71932, 74728, 74730, 75462, 75479, 75514, 78081, 79588, 80287, 80364, 80369, 86440, 87615, 100251, 115277, 116085, 116988, 116994, 118039, 121688, 124125, 124894, 124963, 124983, 125645, 129146, 130455, 131110, 134115, 134839, 135501, 135556, 135822, 136605, 138463, 139112, 140076, 140096, 140669, 142583, 146816, 148593, 150069, 151573, 156160, 157916, 157950, 162512, 165179, 166883, 167750, 169855, 171735, 175663, 178480, 180128, 180166, 183785, 186187, 186223, 186770, 192404, 195890, 196962, 197537, 204620, 204662, 208656, 214580, 216405, 219456, 228400, 242710, 245306, 246541, 257042, 258603, 259212, 260861, 262220, 263449, 269280, 279878, 284592, 284879, 287780, 294185, 298337, 304449, 337609, 346968, 348807, 392459, 407907, 413602, 418241, 432793, 435367, 436220, 442413, 444424, 464188, 465903, 471998, 472670, 475666, 475886, 478915, 493145, 494679, 500125, 518613, 518774, 521029, 544908, 548568, 548975, 563611, 571687, 582699, 601562, 616158, 618545, 641601, 643554, 644676, 656208, 685844, 689464, 689877, 699610, 708195, 743030, 743081, 743104, 760052, 770812, 780632, 788089, 789573, 802828, 805499, 813641, 813912, 814541, 818230, 818729, 822039, 839000, 851901, 871728, 889775, 891335, 899628, 914647, 938664, 940966, 967252, 975942, 993094, 1007611, 1041902, 1099506, 1101617, 1133738, 1165457, 1240180, 1278606, 1285098, 1289863, 1410781, 1428261, 1538857, 1578936, 1595692, 1604788, 1630586, 1634647]
# [10881]
# [9965]
# Time Needed:  65.15690612792969

# %% [markdown]
# ## Removing 10% of edges

# %%
#Removing random edges
tstart = time.time()

threshold = 0.1
counter = 0
new_edges = edge_list
while counter < total_edges*threshold:
  idx = randSelect(len(new_edges))
  for neighbor in new_edges[idx]:
    x = randEdge(threshold)
    if x:
      new_edges[idx].remove(neighbor)
      counter+=1
  
new_edges_num = 0

for item in edge_list:
  new_edges_num+=len(item)

tend = time.time
teleport Vector and Running PageRank

# %%
#Creating Teleport vector
tstart = time.time()
teleport = tpVector(new_edges)
tend - time.time()
print("Time Needed: ", tend-tstart)
#print(teleport)
# Out:
# Time Needed:  -0.6863946914672852

# %%
tstart = time.time()
ranking,iterations = pagerank(new_edges, 0.85, 10**-6, teleport)
tend = time.time()

print("Time Needed: ", tend-tstart)
# Out:
# Time Needed:  122.53067326545715

# %%
for i in range(10):
    print(ranking[i])

print("Iterations: ", iterations)
# Out:
# 4.709922975579043e-164
# 4.709922975579043e-164
# 4.709922975579043e-164
# 4.709922975579043e-164
# 4.709922975579043e-164
# 3.740850305504716e-13
# 4.709922975579043e-164
# 1.4694959683806618e-161
# 4.709922975579043e-164
# 4.709922975579043e-164
# Iterations:  2226

# %% [markdown]
# ## Removing 20% of edges

# %%
#Removing random edges
tstart = time.time()
threshold = 0.2
counter = 0
new_edges = edge_list
while counter < total_edges*threshold:
  idx = randSelect(len(new_edges))
  for neighbor in new_edges[idx]:
    x = randEdge(threshold)
    if x:
      new_edges[idx].remove(neighbor)
      counter+=1
  
new_edges_num = 0

for item in edge_list:
  new_edges_num+=len(item)

tend = time.time()
for i in range(10):
  print(new_edges[i])

print("Time Needed: ", tend-tstart)
# Out:
# [87]
# [143]
# [161]
# [521]
# [332]
# []
# [739]
# [463, 549, 1574, 2137, 3169, 3208, 3390, 3971, 4496, 4892, 5015, 5302, 5354, 5910, 6045, 7618, 7772, 8275, 8583, 8687, 8715, 8760, 8960, 9281, 9291, 9603, 9868, 9960, 10595, 10659, 11032, 11452, 11793, 11916, 12108, 13188, 13217, 13816, 13838, 13883, 14098, 14422, 14609, 15720, 15773, 16759, 17660, 18298, 18301, 18824, 19884, 19896, 20451, 20722, 20798, 20984, 21305, 21386, 23180, 23506, 23576, 23851, 24471, 24536, 24751, 25377, 25378, 25624, 26102, 26105, 26118, 26192, 26304, 26353, 26468, 26762, 26873, 27377, 27378, 27390, 27391, 27487, 27494, 27519, 27544, 27587, 27605, 29516, 29590, 29703, 29768, 31469, 33962, 35393, 35526, 36293, 36739, 37855, 38178, 38188, 38698, 39409, 39583, 40134, 40459, 42237, 42486, 43714, 45311, 45563, 45641, 45878, 47158, 47874, 52280, 55041, 58119, 59029, 59783, 60640, 61772, 67615, 69121, 69302, 71929, 71932, 74728, 74730, 75462, 75479, 78081, 79588, 80287, 80369, 86440, 100251, 115277, 116988, 116994, 118039, 121688, 124894, 124963, 124983, 125645, 130455, 131110, 134839, 135501, 135556, 135822, 138463, 139112, 140076, 140096, 146816, 148593, 150069, 151573, 156160, 162512, 165179, 166883, 167750, 169855, 171735, 178480, 180128, 180166, 183785, 186223, 186770, 192404, 195890, 197537, 204620, 208656, 214580, 216405, 219456, 228400, 242710, 246541, 257042, 259212, 262220, 263449, 269280, 279878, 284592, 284879, 294185, 298337, 337609, 346968, 348807, 407907, 413602, 418241, 435367, 436220, 442413, 444424, 464188, 465903, 471998, 472670, 478915, 493145, 494679, 500125, 518774, 521029, 544908, 548568, 548975, 571687, 582699, 601562, 616158, 618545, 644676, 656208, 685844, 689877, 699610, 708195, 743030, 743081, 743104, 770812, 788089, 789573, 802828, 805499, 813912, 814541, 818729, 822039, 839000, 851901, 871728, 889775, 899628, 914647, 938664, 967252, 975942, 993094, 1007611, 1041902, 1099506, 1101617, 1133738, 1240180, 1278606, 1285098, 1289863, 1410781, 1538857, 1578936, 1604788, 1630586, 1634647]
# []
# [9965]
# Time Needed:  27.827009916305542

# %%
len(new_edges)
# Out:
# 1634989

# %%
len(lines)
# Out:
# 1634989

# %% [markdown]
# ### Creating Teleport Vector and Running PageRank

# %%
#Creating Teleport vector
tstart = time.time()

teleport = tpVector(new_edges)

tend = time.time()
print("Time Needed: ", tend-tstart)
# Out:
# Time Needed:  0.6502556800842285

# %%
tstart = time.time()
ranking,iterations = pagerank(new_edges, 0.85, 10**-6, teleport)
tend = time.time()

print("Time Needed: ", tend-tstart)
# Out:
# Time Needed:  74.85278344154358

# %%
for i in range(10):
    print(ranking[i])
print("Iterations: ", iterations)
# Out:
# 3.5440082089495185e-106
# 3.5440082089495185e-106
# 3.5440082089495185e-106
# 3.5440082089495185e-106
# 3.5440082089495185e-106
# 3.740850305504716e-13
# 3.5440082089495185e-106
# 9.356181671626759e-104
# 3.740850305504716e-13
# 3.5440082089495185e-106
# Iterations:  1406

# %% [markdown]
# # Graph 6: EDU

# %%
# Set Up the Graph Name here

graphName = "wb-edu.txt"

# %% [markdown]
# ## Data Processing

# %%
# Data Processing

lines, rows = readText(directory+graphName)
lines, vertices,total_edges = rmRed(lines)

lines = convertStrNum(lines)
# print(lines)

print("Number of Nodes: ", vertices)
print("Number of Edges: ", total_edges)
# Out:
# Number of Nodes:  9845725
# Number of Edges:  57156537

# %% [markdown]
# ## Creating the Edge List

# %%
#Creating the edge list
tstart = time.time()
edge_list = []

for line in lines:
  edge = line
  edge.pop(0)
  edge.pop(0)
  
  for number in edge:
    if not isinstance(number, int):
      edge.remove(number)
  
  edge_list.append(edge)

tend = time.time()
for i in range(10):
  print(edge_list[i])

print("Time Needed: ", tend-tstart)
# Out:
# []
# []
# [14]
# [4, 5, 10, 12, 13, 16, 17, 20, 21, 23, 26, 27, 28, 33, 34, 35, 41, 42, 89, 93, 94, 97, 102]
# []
# [4, 6, 9, 39, 40, 102]
# [4, 74, 77]
# [4, 39]
# [4, 39, 61, 99, 105]
# [4, 81]
# Time Needed:  1607.5138075351715

# %% [markdown]
# ## Removing 10% of edges

# %%
#Removing random edges
tstart = time.time()

threshold = 0.1
counter = 0
new_edges = edge_list
while counter < total_edges*threshold:
  idx = randSelect(len(new_edges))
  for neighbor in new_edges[idx]:
    x = randEdge(threshold)
    if x:
      new_edges[idx].remove(neighbor)
      counter+=1
  
new_edges_num = 0

for item in edge_list:
  new_edges_num+=len(item)

tend = time.time()

for i in range(10):
  print(new_edges[i])

print("Time Needed: ", tend-tstart)

# %%
len(new_edges)

# %%
len(lines)

# %% [markdown]
# ### Creating the Teleport Vector and Running PageRank

# %%
#Creating Teleport vector
tstart = time.time()
teleport = tpVector(new_edges)
tend - time.time()
print("Time Needed: ", tend-tstart)
#print(teleport)

# %%
tstart = time.time()
ranking,iterations = pagerank(new_edges, 0.85, 10**-6, teleport)
tend = time.time()

print("Time Needed: ", tend-tstart)

# %%
for i in range(10):
    print(ranking[i])

print("Iterations: ", iterations)

# %% [markdown]
# ## Removing 20% of edges

# %%
#Removing random edges
tstart = time.time()
threshold = 0.2
counter = 0
new_edges = edge_list
while counter < total_edges*threshold:
  idx = randSelect(len(new_edges))
  for neighbor in new_edges[idx]:
    x = randEdge(threshold)
    if x:
      new_edges[idx].remove(neighbor)
      counter+=1
  
new_edges_num = 0

for item in edge_list:
  new_edges_num+=len(item)

tend = time.time()
for i in range(10):
  print(new_edges[i])

print("Time Needed: ", tend-tstart)

# %%
len(new_edges)

# %%
len(lines)

# %% [markdown]
# ### Creating Teleport Vector and Running PageRank

# %%
#Creating Teleport vector
tstart = time.time()

teleport = tpVector(new_edges)

tend = time.time()
print("Time Needed: ", tend-tstart)

# %%
tstart = time.time()
ranking,iterations = pagerank(new_edges, 0.85, 10**-6, teleport)
tend = time.time()

print("Time Needed: ", tend-tstart)

# %%
for i in range(10):
    print(ranking[i])
print("Iterations: ", iterations)
